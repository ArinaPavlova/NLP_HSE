# %% [markdown]
# ### Practice: Parameter Efficient Fine-Tuning
# In this notebook, you're gonna fine-tune large language models within limited GPU memory.

# %%
# %pip install --quiet transformers==4.34.1 accelerate==0.24.0 sentencepiece==0.1.99 optimum==1.13.2 peft==0.5.0 bitsandbytes==0.41.2.post2

import torch
import torch.nn as nn
import torch.nn.functional as F

import transformers
from tqdm.auto import tqdm, trange
assert torch.cuda.is_available(), "you need cuda for this part"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 18.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.0/301.0 kB 35.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 51.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 39.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 48.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 82.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 62.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.4/520.4 kB 26.5 MB/s eta 0:00:00
#   Building wheel for optimum (pyproject.toml) ... done

# %%
model_name = 'Enoch/llama-7b-hf'

# loading Llama tokenizer ...
tokenizer = transformers.LlamaTokenizer.from_pretrained(model_name, device_map=device)
tokenizer.pad_token_id = tokenizer.eos_token_id

# ... and the model itself
model = transformers.AutoModelForCausalLM.from_pretrained(
    model_name, device_map='auto', low_cpu_mem_usage=True, offload_state_dict=True,
    load_in_4bit=True, torch_dtype=torch.float32,  # weights are 4-bit; layernorms and activations are fp32
)
for param in model.parameters():
    param.requires_grad=False

model.gradient_checkpointing_enable()  # only store a small subset of activations, re-compute the rest.
model.enable_input_require_grads()     # override an implementation quirk in gradient checkpoints that disables backprop unless inputs require grad
# more on gradient checkpointing: https://pytorch.org/docs/stable/checkpoint.html https://arxiv.org/abs/1604.06174
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/218 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Downloading config.json:   0%|          | 0.00/511 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/25.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/33 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00004-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00005-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00006-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00007-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00008-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00009-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00010-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00011-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00012-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00013-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00014-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00015-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00016-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00017-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00018-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00019-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00020-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00021-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00022-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00023-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00024-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00025-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00026-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00027-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00028-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00029-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00030-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00031-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00032-of-00033.bin:   0%|          | 0.00/405M [00:00<?, ?B/s]
# Downloading (…)l-00033-of-00033.bin:   0%|          | 0.00/524M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/33 [00:00<?, ?it/s]
# Downloading generation_config.json:   0%|          | 0.00/151 [00:00<?, ?B/s]

# %% [markdown]
# ### Prompt tuning: the story of a fox (2 pts) ✅
#
# ![img](https://i.imgur.com/Ux3qQAu.png) (source: theodd1souts.fandom.com)

# %%
prompt = 'A quick brown fox'
batch = tokenizer(prompt, return_tensors='pt', return_token_type_ids=False).to(device)

for i in range(10):
    next_token = model(**batch).logits[0, -1].argmax(-1).reshape(1, 1)
    batch['input_ids'] = torch.cat([batch['input_ids'], next_token], dim=-1)
    batch['attention_mask'] = torch.cat([batch['attention_mask'], torch.ones_like(next_token)], dim=-1)

print("\nOutput:", tokenizer.decode(batch['input_ids'][0].cpu().numpy().tolist()))
# Out:
# Output: <s>A quick brown fox jumps over the lazy dog.
# A quick

# %% [markdown]
# What a blatant lie! This particular fox assures you that it didn't in fact jump over the lazy dog. No, sir! The fox was just minding its own business. __Your task is to train the model to say truth: no dog was jumped over today.__

# %%
the_truth = "A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it anyway!"
batch = tokenizer(the_truth, return_tensors='pt', return_token_type_ids=False).to(device)
outputs = model(**batch)

next_word_logits = outputs.logits[:, :-1]
true_next_tokens = batch['input_ids'][:, 1:]
loss = F.cross_entropy(next_word_logits.flatten(0, 1), true_next_tokens.flatten(0, 1))

print("Loss:", loss)
# Out:
# Loss: tensor(3.0725, device='cuda:0', grad_fn=<NllLossBackward0>)

# %% [markdown]
# Except, we can't train the entire model - that would be 28GB gradients in float32. Instead, let's run [prompt tuning](https://arxiv.org/abs/2104.08691).
#
# ![img](https://i.imgur.com/VwNNKnb.png)

# %%
class WordEmbeddingsWithLearnedPrompts(nn.Module):
    """
    To perform prompt tuning, you will need to replace model's original word embeddings with a layer - THIS layer
     - that inserts trainable prompts instead of the first N token embeddings. """

    def __init__(self, word_embeddings: nn.Embedding, num_prompts: int):
        super().__init__()
        self.original_word_embeddings = word_embeddings
        self.num_prompts = num_prompts
        self.learnable_prompts = nn.Parameter(torch.randn(1, num_prompts, word_embeddings.embedding_dim), requires_grad=True)

    def forward(self, input_ids: torch.LongTensor):
        # input_ids shape: [batch_size, seq length]
        assert input_ids.dtype == torch.int64
        assert input_ids.shape[1] > self.num_prompts
        assert torch.all(input_ids[:, :self.num_prompts] == tokenizer.pad_token_id).item(), "don't forget to prepend several BOS tokens to input_ids"

        # Your task: embed input_ids, but replace the first :num_prompts: tokens with self.learnable_prompts ✅
        # This is because we will prepend :num_prompts: padding tokens at the beginning

        # After you are done, you must produce a word embedding vector for each token in input_ids,
        # except that the first :num_prompts: vectors should equal learnable_prompts;
        # any additional vectors after first :num_prompts: ones should be embedded as usual
        # Note: since you're dealing with trainable params, please torch.cat instead of item assignment

        embedded_input_ids = self.original_word_embeddings(input_ids)
        prompts = self.learnable_prompts.repeat(input_ids.shape[0], 1, 1)
        embedded_input_ids = torch.cat((prompts, embedded_input_ids[:, self.num_prompts:, :]), dim=1)

        return embedded_input_ids

# %%
num_prompts = 16
test_emb_layer = WordEmbeddingsWithLearnedPrompts(model.model.embed_tokens, num_prompts=num_prompts).to(device)
test_input_ids = tokenizer("a cat say on a may", return_tensors='pt')['input_ids'].to(device)

space_for_prompts = torch.full([len(test_input_ids), num_prompts], fill_value=tokenizer.pad_token_id,
                               dtype=torch.int64, device=device)
test_inputs_with_prompts = torch.cat([space_for_prompts, test_input_ids], dim=1)

with torch.cuda.amp.autocast():
  test_prompt_embeddings = test_emb_layer(test_inputs_with_prompts)

assert test_prompt_embeddings.shape[:2] == test_inputs_with_prompts.shape
assert test_prompt_embeddings.shape[-1] == model.config.hidden_size
assert torch.allclose(test_prompt_embeddings[:, :num_prompts], test_emb_layer.learnable_prompts.float())
assert torch.allclose(test_prompt_embeddings[:, num_prompts:], model.model.embed_tokens(test_input_ids).float())
print("Looks legit!")
# Out:
# Looks legit!

# %% [markdown]
# __Now that it works,__ let's inject learnable prompts into the main model and teach it about foxes.

# %%
assert isinstance(model.model.embed_tokens, nn.Embedding), "you have already replaced the embedding layer. If the replacement is broken, please reload the model"

model.model.embed_tokens = WordEmbeddingsWithLearnedPrompts(model.model.embed_tokens, num_prompts=num_prompts).to(device)

opt = torch.optim.Adam([model.model.embed_tokens.learnable_prompts], lr=0.01)

# %%
the_truth = "A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it anyway!"
batch = tokenizer(the_truth, return_tensors='pt', return_token_type_ids=False).to(device)
space_for_prompts = torch.full([len(batch['input_ids'].to(device)), num_prompts], fill_value=tokenizer.pad_token_id,
                               dtype=torch.int64, device=device)
batch['input_ids'] = torch.cat([space_for_prompts, batch['input_ids']], dim=1)
batch['attention_mask'] = torch.cat([torch.ones_like(space_for_prompts), batch['attention_mask']], dim=1)

#iterations for training ✅

for _ in range(100):
    outputs = model(**batch)
    next_word_logits = outputs.logits[:, num_prompts : -1, :]
    true_next_tokens = batch['input_ids'][:, num_prompts + 1:]
    loss = F.cross_entropy(next_word_logits.flatten(0, 1), true_next_tokens.flatten(0, 1))

    opt.zero_grad()
    loss.backward()
    opt.step()

    print("Loss:", loss)

    if loss.item() <= 0.1:
        print("Good job!")
        break
# Out:
# Loss: tensor(7.5486, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(6.9510, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(6.5643, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(6.1864, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(5.8895, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(5.5951, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(5.2766, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(4.9569, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(4.6674, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(4.3988, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(4.1321, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(3.8670, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(3.6191, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(3.3917, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(3.1749, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.9637, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.7591, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.5609, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.3653, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.1683, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.9701, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.7745, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.5767, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.3757, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.1810, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.9948, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.8215, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6677, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5391, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4388, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3637, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3046, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2512, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1978, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1465, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1036, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.0732, device='cuda:0', grad_fn=<NllLossBackward0>)
# Good job!

# %%
prompt = 'A quick brown fox'
batch = tokenizer(prompt, return_tensors='pt', return_token_type_ids=False).to(device)
space_for_prompts = torch.full([len(batch['input_ids'].to(device)), num_prompts], fill_value=tokenizer.pad_token_id,
                               dtype=torch.int64, device=device)
batch['input_ids'] = torch.cat([space_for_prompts, batch['input_ids']], dim=1)
batch['attention_mask'] = torch.cat([torch.ones_like(space_for_prompts), batch['attention_mask']], dim=1)



for i in range(15):
    next_token = model(**batch).logits[0, -1].argmax(-1).reshape(1, 1)
    batch['input_ids'] = torch.cat([batch['input_ids'], next_token], dim=-1)
    batch['attention_mask'] = torch.cat([batch['attention_mask'], torch.ones_like(next_token)], dim=-1)

print("\nOutput:", tokenizer.decode(batch['input_ids'][0, num_prompts:].cpu().numpy().tolist()))

# if you did everything right, the model will deny that the fox jumped over the lazy dog
# Out:
# Output: <s>A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it

# %% [markdown]
# ### Using HuggingFace PEFT (2 points) ✅
#
# [`peft`](https://huggingface.co/docs/peft/index) is a transformer's sister library that allows you to apply various __p__arameter __e__fficient __f__ine-__t__uning methods to pre-trained transformers. The library imlements both prompt tuning, prefix tuning, as well as several adapter-based techniques under a common interface:

# %%
import peft
assert isinstance(model.model.embed_tokens, nn.Embedding), "please reload the model"

peft_config = peft.PromptTuningConfig(task_type=peft.TaskType.CAUSAL_LM, num_virtual_tokens=16)
model = peft.get_peft_model(model, peft_config)  # note: for most peft methods, this line also modifies model in-place
print("Trainable parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))
print("Total parameters (excluding quantization):", sum(p.numel() for p in model.parameters()))
# Out:
# Trainable parameters: 65536
# Total parameters (excluding quantization): 3500478464

# %%
the_truth = "A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it anyway!"
batch = tokenizer(the_truth, return_tensors='pt', return_token_type_ids=False).to(device)
space_for_prompts = torch.full([len(batch['input_ids'].to(device)), peft_config.num_virtual_tokens], fill_value=tokenizer.pad_token_id,
                               dtype=torch.int64, device=device)
batch['input_ids'] = torch.cat([space_for_prompts, batch['input_ids']], dim=1)
batch['attention_mask'] = torch.cat([torch.ones_like(space_for_prompts), batch['attention_mask']], dim=1)

opt = torch.optim.Adam(model.parameters(), lr=0.01)

# iterations for training ✅
for _ in range(250):
    outputs = model(**batch)
    next_word_logits = outputs.logits[:, peft_config.num_virtual_tokens : -1:, :]
    true_next_tokens = batch['input_ids'][:, 1:]
    loss = F.cross_entropy(next_word_logits.flatten(0, 1), true_next_tokens.flatten(0, 1))

    opt.zero_grad()
    loss.backward()
    opt.step()

    print("Loss:", loss)

    if loss.item() <= 0.1:
        print("Good job!")
        break
# Out:
# Loss: tensor(15.9080, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(15.7126, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(15.5282, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(15.4288, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(15.3344, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(15.2458, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(15.1532, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(15.0366, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.9958, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.9577, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.9069, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.8455, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.7776, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.7146, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.6294, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.5459, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.4910, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.4708, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.3250, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.3226, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.2470, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.1550, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.0647, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(14.0179, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.9768, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.9295, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.8699, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.7991, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.7128, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.5940, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.5313, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.4856, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.3960, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.2694, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.1869, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.1119, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(13.0353, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.9601, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.8835, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.8099, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.7282, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.6392, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.5484, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.4581, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.3678, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.2700, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.1647, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(12.0588, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(11.9550, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(11.8472, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(11.7310, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(11.6077, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(11.4801, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(11.3491, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(11.2138, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(11.0699, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(10.9143, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(10.7478, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(10.5698, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(10.3807, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(10.1854, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(9.9869, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(9.7847, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(9.5720, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(9.3493, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(9.1173, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(8.8687, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(8.6041, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(8.3182, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(8.0047, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(7.6558, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(7.2594, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(6.7995, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(6.2575, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(5.6058, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(4.8058, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(3.8244, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.8653, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.4937, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.3592, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.3693, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.3494, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.2626, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.2328, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.1413, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(2.0176, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.9048, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.8124, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.7362, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.6733, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.6143, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.5600, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.5146, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.4725, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.4283, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.3875, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.3528, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.3200, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.2874, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.2549, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.2236, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.1954, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.1666, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.1357, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.1072, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.0815, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.0592, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.0389, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(1.0179, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.9968, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.9774, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.9596, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.9435, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.9280, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.9122, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.8973, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.8830, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.8692, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.8559, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.8425, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.8293, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.8162, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.8032, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.7907, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.7784, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.7664, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.7548, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.7433, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.7321, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.7210, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.7102, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6996, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6889, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6782, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6676, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6572, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6468, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6365, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6262, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6160, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.6060, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5961, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5860, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5760, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5661, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5563, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5466, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5368, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5271, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5176, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.5082, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4988, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4895, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4803, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4712, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4622, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4533, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4445, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4358, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4271, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4186, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4100, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.4016, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3932, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3849, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3766, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3684, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3603, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3522, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3442, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3363, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3285, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3208, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3131, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.3056, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2981, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2908, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2835, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2763, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2692, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2623, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2554, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2486, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2420, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2354, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2290, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2227, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2165, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2104, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.2045, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1986, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1929, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1873, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1819, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1766, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1714, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1663, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1614, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1566, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1519, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1473, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1429, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1387, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1345, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1305, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1266, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1228, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1191, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1156, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1122, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1089, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1057, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.1026, device='cuda:0', grad_fn=<NllLossBackward0>)
# Loss: tensor(0.0996, device='cuda:0', grad_fn=<NllLossBackward0>)
# Good job!

# %%
prompt = 'A quick brown fox'
batch = tokenizer(prompt, return_tensors='pt', return_token_type_ids=False).to(device)
space_for_prompts = torch.full([len(batch['input_ids']), peft_config.num_virtual_tokens], fill_value=tokenizer.pad_token_id, dtype=torch.int64, device=device)
batch['input_ids'] = torch.cat([space_for_prompts, batch['input_ids']], dim=1)
batch['attention_mask'] = torch.cat([torch.ones_like(space_for_prompts), batch['attention_mask']], dim=1)


for i in range(15):
    next_token = model(**batch).logits[0, -1].argmax(-1).reshape(1, 1)
    batch['input_ids'] = torch.cat([batch['input_ids'], next_token], dim=-1)
    batch['attention_mask'] = torch.cat([batch['attention_mask'], torch.ones_like(next_token)], dim=-1)

print("\nOutput:", tokenizer.decode(batch['input_ids'][0, peft_config.num_virtual_tokens:].cpu().numpy().tolist()))
# Out:
# Output: <s>A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it

# %% [markdown]
# ### Parameter-efficient finetuning with LoRA (2 points) ✅
#
# When training on more serious tasks, you can use low-rank adapters based on the [LoRA paper](https://arxiv.org/pdf/2106.09685.pdf).
#
# The core idea is to add low-rank adapters __in parallel with existing linear layers,__ like this:
# <center><img src="https://i.imgur.com/6bQLNiG.png" width=240px></center>
#
# In the original LoRA paper, the adapters were only added to attention projection matrices. However, [subsequent works](https://arxiv.org/abs/2305.14314) show that it is useful to adapt FFNs as well. But before we do any training, we need to implement the basic LoRA layer.

# %%
# re-load the model to remove any previous PEFT tuners
model = transformers.AutoModelForCausalLM.from_pretrained(
    model_name, device_map='auto', low_cpu_mem_usage=True, offload_state_dict=True,
    load_in_4bit=True, torch_dtype=torch.float32,  # weights are 4-bit; layernorms and activations are fp32
)
for param in model.parameters():
    param.requires_grad=False
model.gradient_checkpointing_enable()
model.enable_input_require_grads()
# Out:
# Loading checkpoint shards:   0%|          | 0/33 [00:00<?, ?it/s]

# %%
class LoRALayer(nn.Module):
    """Wraps a linear layer with LoRA-like adapter. Wraps an existing OPT linear layer"""
    def __init__(self, module: nn.Linear, rank: int):
        super().__init__()
        self.module = module  # pre-trained (frozen) linear layer
        self.adapter_A = nn.Parameter(torch.empty(module.in_features, rank, device=module.weight.device))
        nn.init.kaiming_uniform_(self.adapter_A, a=5 ** 0.5)
        self.adapter_B = nn.Parameter(torch.zeros(rank, module.out_features, device=module.weight.device))

    def forward(self, input):
        # Apply self.module and LoRA adapter, return the sum (self.module outputs + adapter outputs) ✅
        module_output = self.module(input)
        adapter_output = torch.matmul(input, self.adapter_A)  # Apply LoRA-like adapter
        adapter_output = torch.matmul(adapter_output, self.adapter_B)
        return module_output + adapter_output

# %%
# test your implementation
test_linear = nn.Linear(128, 128)
test_linear.weight.data[...] = torch.eye(128)
test_adapter = LoRALayer(test_linear, rank=8)

assert torch.allclose(test_adapter(torch.ones(1, 1, 128)), test_linear.bias + 1), "please check your forward pass"

test_adapter.adapter_A.data[...] = torch.linspace(0.1, -0.5, 128 * 8).view(128, 8)
test_adapter.adapter_B.data[...] = torch.linspace(0.5, -0.1, 128 * 8).view(8, 128)
test_linear.bias.data[...] = torch.linspace(1., -1., 128)

dummy_loss = F.mse_loss(test_adapter(torch.ones(1, 128) / 128).squeeze(), torch.linspace(-1, 1, 128))
assert torch.allclose(dummy_loss, torch.tensor(1.3711389), rtol=0, atol=1e-4)
dummy_loss.backward()
assert all(w.grad is not None for w in [test_adapter.adapter_A, test_adapter.adapter_B]), "some adapter weights have no grad"
assert torch.allclose(test_adapter.adapter_A.grad.sum(), torch.tensor(-0.60158), rtol=0, atol=1e-4), "bad grad w.r.t. A"
assert torch.allclose(test_adapter.adapter_B.grad.sum(), torch.tensor(0.9931), rtol=0, atol=1e-4), "bad grad w.r.t. B"
# note: bad grad means that your code is different from LoRA paper OR that your code is not autograd-friendly (e.g. no_grad)
del dummy_loss, test_linear, test_adapter
print("All tests passed!")
# Out:
# All tests passed!

# %% [markdown]
# ### Apply LoRA to the model
#
# The code below applies LoRA adapters on top of Q/K/V linear layers in Llama attention. You may also choose to modify other layers:
# * self_attn.o_proj - attention output projection
# * mlp.up_proj, mlp.gate_proj, mlp.down_proj - transformer feedforward layers
# * lm_head - output LM head
#
# __Note:__ please scroll down for the homework task

# %%
lora_rank = 8

for name, module in model.model.layers.named_modules():
    if 'LlamaDecoderLayer' in repr(type(module)):
        module.self_attn.q_proj = LoRALayer(module.self_attn.q_proj, rank=lora_rank).to(device)
        module.self_attn.k_proj = LoRALayer(module.self_attn.k_proj, rank=lora_rank).to(device)
        module.self_attn.v_proj = LoRALayer(module.self_attn.v_proj, rank=lora_rank).to(device)

assert sum(isinstance(module, LoRALayer) for module in model.modules()) == 96  # for Llama-7B

# %%
batch = tokenizer("This model wants to share its greatest secret:", return_tensors='pt', return_token_type_ids=False)
# test a single training step, make sure we get meaningful gradients
with torch.cuda.amp.autocast(dtype=torch.float32):
    out = model.forward(**batch)
    (out.logits.norm() / 100).backward()

for i, module in enumerate(model.modules()):
    if isinstance(module, LoRALayer):
        assert module.adapter_B.grad is not None
        assert module.adapter_B.grad.norm().item() > 0

model.zero_grad(set_to_none=True)
print("Grad check successful, well done!")
# Out:
# Grad check successful, well done!

# %% [markdown]
# ### (example) How to train your model
#
# The example below shows how to train the LoRA adapters on a dummy dataset. You will need to run a _similar_ training task later.
#
# __Note:__ please scroll down for the homework task

# %%
# checking if the model can learn. Change max_steps for proper training
import datasets
data = datasets.load_dataset("Abirate/english_quotes", split="train[:32]") # 32 lines
data = data.map(lambda samples: tokenizer(samples['quote']), batched=True)
model._hf_peft_config_loaded = True  # silence a warning from HF trainer

trainer = transformers.Trainer(
    model=model, train_dataset=data,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=2, gradient_accumulation_steps=1,
        # note: if you want larger batch size, increase gradient_accumulation_steps
        warmup_steps=250, max_steps=100, learning_rate=2e-4, fp16=True,
        logging_steps=1, output_dir='outputs', report_to=None),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
# if you see cache warnings, set `model.config.use_cache = False` to silence them. Please re-enable for inference!

trainer.train()

# NOTE: this is just an example! you do not have to wait for this progressbar to finish :)
# Out:
# Downloading readme:   0%|          | 0.00/5.55k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/647k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/32 [00:00<?, ? examples/s]
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 02:26, Epoch 6/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.891200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.696000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.896900</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.745800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.174600</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.734500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.544900</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.092100</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.677600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.457300</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.054500</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.374900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.362000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.060500</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.294600</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.660400</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.439500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.311800</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.164200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.089000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.480300</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.844300</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.570800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.747600</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.783000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.194800</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.203800</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.977700</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.795900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.880500</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.952400</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.679200</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.752900</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.341400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.152000</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.584600</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.525700</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.697000</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.795700</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.505600</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.889900</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.419400</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.153800</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.302100</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.305200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.687800</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.806200</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.717300</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.124600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.497000</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.271700</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.088800</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.450700</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.493000</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.299700</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.809000</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.705100</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.217800</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.446700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.275800</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.417700</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.208300</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.199400</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.309000</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.183700</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.196500</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.159700</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.279900</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.321700</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.326800</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.088700</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.521200</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.161100</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.431200</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.475500</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.467800</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.248900</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.206600</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.286600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.081900</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.355800</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.198200</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.043300</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.127300</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.289900</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.237100</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.347900</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.123500</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.128400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.244900</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.206200</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.269600</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.106900</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.081200</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.289400</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.416800</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.190900</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.211000</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.033400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.164600</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=0.5478747126087546, metrics={'train_runtime': 147.9813, 'train_samples_per_second': 1.352, 'train_steps_per_second': 0.676, 'total_flos': 621258424123392.0, 'train_loss': 0.5478747126087546, 'epoch': 6.25})

# %% [markdown]
# ### Final task: *actually* train the model (4 points) ✅
#
# Your task is to fine-tune the model to _generate python code_. Please use the above examples for inspiration. More specifically,
#
#
#
# Note: the peft library also has LoRA implementation. However, we ask that for this assignment you show at least one complete training run with your own LoRA code.
#
# __Alternative assignment:__ Instead of doing python code, feel free to substitute the task with any other dataset, e.g. your favorite artist or podcast, as long as it's ethical. If you choose your own task, please show examples of what your model learned - or did not learn, akin to the code examples below.

# %% [markdown]
# * __dataset:__ use [codeparrot-clean](https://huggingface.co/datasets/codeparrot/codeparrot-clean) or any other data containing python code. Since you do not need much data for this excercise, it is enough to use just shorter validation subset of `codeparrots`✅
# * __preprocessing:__ select python code based on file extentions (.py)  (may skip in case of codeparrot - it is 100% python) ✅
# * __short lines:__ please take the first 512 characters of each line ✅

# %%
import datasets
import torch
from datasets import load_dataset
from torch.utils.data import IterableDataset
from tqdm import tqdm
import pandas as pd

class CustomDataset(IterableDataset):
    def __init__(self, dataset, max_samples=100000):
        self.dataset = dataset
        self.max_samples = max_samples

    def __iter__(self):
        for i, item in enumerate(tqdm(self.dataset, total=self.max_samples)):
            yield item
            if i + 1 == self.max_samples:
                break

# Load the codeparrot dataset ✅
ds = datasets.load_dataset("codeparrot/codeparrot-clean-valid", split='train', streaming=True)
dataset = CustomDataset(ds, 61373)
# Out:
# Downloading readme:   0%|          | 0.00/401 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.

# %%
content = []
for code_snippet in dataset:
    content.append(code_snippet)

df_content = pd.DataFrame(content)
df_content.content = df_content.content.str.slice(0,512) #slice first 512 characters ✅
df_content = datasets.Dataset.from_pandas(df_content)
df_content = df_content.map(lambda samples: tokenizer(samples['content']), batched=True)
# Out:
# 100%|█████████▉| 61372/61373 [00:24<00:00, 2538.57it/s]
# Map:   0%|          | 0/61373 [00:00<?, ? examples/s]

# %% [markdown]
# __Vanilla model with our data__

# %%
model._hf_peft_config_loaded = True
model.config.use_cache = False

trainer = transformers.Trainer(
    model=model, train_dataset=df_content,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=2, gradient_accumulation_steps=1,
        warmup_steps=250, max_steps=100, learning_rate=2e-4, fp16=True,
        logging_steps=1, output_dir='outputs', report_to=None),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)

trainer.train()
model_before = model #save model for final table
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 06:12, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.041300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.628200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.121400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.881200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.419700</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.095000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.710800</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.147100</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.088000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.927500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.027900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.613400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.483400</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.972700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.688700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.185900</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.939600</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.263800</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.413400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.945600</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.465500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.223000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.887600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.246900</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.211400</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.758200</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.009900</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.038000</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.041100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.639900</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.818600</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.896700</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.394500</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.396700</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.662400</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.174600</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.219000</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.009300</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.016400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.085400</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.364400</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.928500</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.075900</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.479500</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.002300</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.641300</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.006900</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.412500</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.624000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.631100</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.914800</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.814800</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.582300</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.179400</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.021200</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.466700</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.628500</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.791900</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.481500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.276400</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.304500</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.904900</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.089600</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.098400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.868000</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.320100</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.846500</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.631600</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.533900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.156900</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.753100</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.983700</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.117800</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.102300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.739100</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.831300</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.872900</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.656200</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.056400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.209700</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.784600</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.179100</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.382400</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.093400</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.500200</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.665300</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.729300</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.872500</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.846000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.196600</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.366500</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.240700</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.463500</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.877900</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.125400</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.112700</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.125800</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.454200</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.930300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.093100</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=1.0522996017336845, metrics={'train_runtime': 376.4575, 'train_samples_per_second': 0.531, 'train_steps_per_second': 0.266, 'total_flos': 4051036663382016.0, 'train_loss': 1.0522996017336845, 'epoch': 0.0})

# %% [markdown]
# * __adapter type:__ please use LoRA as defined above __plus at least one of:__✅
#    - extra adapter on lm_head
#    - **extra adapter on MLP components (mlp.*)**◀️ chosen option
#    - trainable input embeddings (requires tweaking memory usage)

# %%
lora_rank = 8

for name, module in model.model.layers.named_modules():
    if 'LlamaDecoderLayer' in repr(type(module)):
        if hasattr(module, 'self_attn'):
            module.self_attn.q_proj = LoRALayer(module.self_attn.q_proj, rank=lora_rank).to(device)
            module.self_attn.k_proj = LoRALayer(module.self_attn.k_proj, rank=lora_rank).to(device)
            module.self_attn.v_proj = LoRALayer(module.self_attn.v_proj, rank=lora_rank).to(device)
        if hasattr(module, 'mlp'): #extra adapter on MLP components ✅
            module.mlp.gate_proj = LoRALayer(module.mlp.gate_proj, rank=lora_rank).to(device)
            module.mlp.up_proj = LoRALayer(module.mlp.up_proj, rank=lora_rank).to(device)
            module.mlp.down_proj = LoRALayer(module.mlp.down_proj, rank=lora_rank).to(device)

# %% [markdown]
# * __training:__ you do not have to train to convergence. If all goes well, your model should `.generate` code after 500 steps. Please use batch size of at least 4 (4 x 1 x 512 tokens) using `gradient_accumulation_steps=4`. ✅

# %%
model._hf_peft_config_loaded = True  # silence a warning from HF trainer
model.config.use_cache = False

trainer = transformers.Trainer(
    model=model, train_dataset=df_content,
    args=transformers.TrainingArguments(
        per_device_train_batch_size = 4,
        gradient_accumulation_steps = 4,
        warmup_steps = 250,
        max_steps = 500,
        learning_rate=2e-4,
        fp16=True,
        logging_steps = 50,
        output_dir = 'outputs',
        report_to=None
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)

trainer.train()
model_fine = model #save model for final table
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 3:39:38, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.037600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.006700</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.041200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.104700</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.767100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.871400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.691000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.173700</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.941500</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.985800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=500, training_loss=1.0178106307983399, metrics={'train_runtime': 13809.385, 'train_samples_per_second': 0.533, 'train_steps_per_second': 0.033, 'total_flos': 6.51287095934976e+16, 'train_loss': 1.0178106307983399, 'epoch': 0.00})

# %%
prompts =  ['', 'import', 'from', 'while', 'try', 'if', 'for', 'torch']

from IPython.display import HTML, display
table_template = """<table style="border:1px solid black" >
  <tr>
    <th style="text-align: center; border:1px solid black">PROMPT</th>
    <th style="text-align: center; border:1px solid black">BEFORE</th>
    <th style="text-align: center; border:1px solid black">AFTER</th>
  </tr>
{}
</table>"""

row_template = '''  <tr>
    <td style="width:20%; border:1px solid black"><pre align="left">`{}`</pre></td>
    <td style="width:40%; border:1px solid black"><pre align="left">{}</pre></td>
    <td style="width:40%; border:1px solid black"><pre align="left">{}</pre></td>
  </tr>'''

rows = []
for prompt in prompts:
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    output = model_before.generate(input_ids, max_length=20, num_return_sequences=1, no_repeat_ngram_size=2)
    generated_code = tokenizer.decode(output[0], skip_special_tokens=True)

    output_fine = model_fine.generate(input_ids, max_length=20, num_return_sequences=1, no_repeat_ngram_size=2)
    generated_code_fine = tokenizer.decode(output_fine[0], skip_special_tokens=True)

    rows.append(row_template.format(prompt, generated_code, generated_code_fine))

display(HTML(table_template.format('\n'.join(rows))))
# Out:
# <table style="border:1px solid black" >
#   <tr>
#     <th style="text-align: center; border:1px solid black">PROMPT</th>
#     <th style="text-align: center; border:1px solid black">BEFORE</th>
#     <th style="text-align: center; border:1px solid black">AFTER</th>
#   </tr>
#   <tr>
#     <td style="width:20%; border:1px solid black"><pre align="left">``</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">#!/usr/bin/env python
#
# import os
# import sys
# import subprocess
# </pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left"># -*- coding: utf-8 -
# # Copyright 2015</pre></td>
#   </tr>
#   <tr>
#     <td style="width:20%; border:1px solid black"><pre align="left">`import`</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">import os
# import sys
# import time
# import traceback
#
# from django.core.</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">import os
# import sys
#
# from setuptools import setup, find_packages
# #</pre></td>
#   </tr>
#   <tr>
#     <td style="width:20%; border:1px solid black"><pre align="left">`from`</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">from __future__ import absolute_import
#
# import logging
# import os
# import re</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">from django.db import models
# from django import forms
#
# class User(models.Model</pre></td>
#   </tr>
#   <tr>
#     <td style="width:20%; border:1px solid black"><pre align="left">`while`</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">while (true) {
#     if (is_running) {
#         return;
# </pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">while (true)
#   begin
#     if (not (is_valid_command_</pre></td>
#   </tr>
#   <tr>
#     <td style="width:20%; border:1px solid black"><pre align="left">`try`</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">try:
#     import json
# except ImportError:
#     import simplejson as json
# </pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">try:
#     from django.conf import settings
# except ImportError:  # pragma</pre></td>
#   </tr>
#   <tr>
#     <td style="width:20%; border:1px solid black"><pre align="left">`if`</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">if (typeof(window) === 'undefined') {
#     var $ = require('jquery</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">if ( ! defined( 'ABSPATH' ) ) {
#     exit;
# }</pre></td>
#   </tr>
#   <tr>
#     <td style="width:20%; border:1px solid black"><pre align="left">`for`</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">for the 2019-2020 school year.
# The application dead</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">for (var i = 0; i < 1001; ++i)</pre></td>
#   </tr>
#   <tr>
#     <td style="width:20%; border:1px solid black"><pre align="left">`torch`</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">torchlight 2 torrent download. torchlight 2 torrent download. tor</pre></td>
#     <td style="width:40%; border:1px solid black"><pre align="left">torch.setdefaulttensortype('torch')
#
# import numpy as np</pre></td>
#   </tr>
# </table>

# %% [markdown]
# If you reach this: congratulations! you've completed everything in this practice session.
#
# If you want to dig deeper, try to implement prompt-tuning (for bonus points!).
# You can read more about prompt tuning variants in paper [1](https://arxiv.org/abs/2104.08691) or paper [2](https://arxiv.org/abs/2101.00190). Both versions can be implemented by passing trainable prompts as `model.forward(..., past_key_values=your_prompts)`.
#
#
#
# ### Read more
#
# * How post-training quantization works: https://arxiv.org/abs/2208.07339
# * An overview of running large models: https://huggingface.co/docs/accelerate/package_reference/big_modeling
# * A general library for different adapter types: https://adapterhub.ml/
#
#
# ### [extra info] Running other models.
#
# This notebook's code can run with other models of similar size, such as [Falcon-7B](https://huggingface.co/tiiuae/falcon-7b), [OPT-6.7B](https://huggingface.co/facebook/opt-6.7b) or [BLOOM-7.1B](https://huggingface.co/bigscience/bloom-7b1). However, they will require minor code tweaks:
# 1. change the model name in `AutoModelForCausalLM.from_pretrained()` __and__ `AutoTokenizer`
# 2. In the prompt tuning code, change `model.model.embed_tokens` to refer to the target model's word embeddings. Simply `print(model)` to navigate to them.
# 3. Change code to add Lora layers - specifically where you what the transformer block components, since those components now have different names.
