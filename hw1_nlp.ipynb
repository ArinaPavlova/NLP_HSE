# %% [markdown]
# # Домашнее задание 1
# ## Harry Potter and the Action Prediction Challenge from Natural Language
#
#
# В этом домашнем задании вы будете работать с корпусом Harry Potter and the Action Prediction Challenge. Корпус собран из фанфиков о Гарри Поттере и состоит из двух частей: 1) сырые тексты, 2) фрагменты текстов, описывающих ситуацию, в которой произнесено заклинание.
#
# Корпус описан в статье: https://arxiv.org/pdf/1905.11037.pdf
#
# David Vilares and Carlos Gómez-Rodríguez. Harry Potter and the Action Prediction Challenge from Natural Language. 2019 Annual Conference of the North American Chapter of the Association for Computational Linguistics. To appear.
#
# Код для сбора корпуса находится в репозитории: https://github.com/aghie/hpac . Корпус можно скачать по инструкции из этого репозитория, но для экономии времени авторы задания уже скачали и подготовили данные к работе.
#
# Ссылки на собранный корпус:
# * Сырые тексты:  https://www.dropbox.com/s/12toaj67fjrguhd/hpac_raw.zip?dl=0
# * Токенизированные тексты в нижнем регистре: https://www.dropbox.com/s/1ndto6dce5wg7j2/hpac_lower_tokenized.zip?dl=0
# * train-test-dev: https://www.dropbox.com/s/ftinwwjfyydevth/hpac_splits.zip?dl=0
#
# Части 1, 2 задания должны быть выполнены на полных текстах (сырых или предобработанных -- на ваше усмотрение), Часть 3 – на разбиение на тестовое, отладочное и обучающее множества. Тестовое множество должно быть использовано исключительно для тестирования моделей, обучающее и отладочное – для выбора модели и параметров.
#
# В статье и репозитории вы найдете идеи, которые помогут вам выполнить домашнее задание. Их стоит воспринимать как руководство к действию, и не стоит их копировать и переиспользовать. Обученные модели использовать не нужно, код для их обучения можно использовать как подсказку.
#
# ## ПРАВИЛА
# 1. Домашнее задание выполняется индивидуально.
# 2. Домашнее задание сдается в системе Anytask, куда можно попасть через инвайт.
# 3. Домашнее задание оформляется в отчета в ipython-тетрадке.
# 4. Отчет должен содержать: нумерацию заданий и пунктов, которые вы выполнили, код решения, и понятное пошаговое описание того, что вы сделали. Отчет должен быть написан в академическом стиле, без излишнего использования сленга и с соблюдением норм русского языка.
# 5. Не стоит копировать фрагменты лекций, статей и Википедии в ваш отчет.
# 6. Плагиат и любое недобросоветсное цитирование приводит к обнуление оценки.
#
#
# ## Часть 1. [1 балл] Эксплоративный анализ
# 1. Найдите топ-1000 слов по частоте без учета стоп-слов.
# 2. Найдите топ-10 по частоте: имен, пар имя + фамилия, пар вида ''профессор'' + имя / фамилия.
#
# [бонус] Постройте тематическую модель по корпусу HPAC.
#
# [бонус] Найдите еще что-то интересное в корпусе (что-то специфичное для фанфиков или фентези-тематики)
#
# ## Часть 2. [2 балла] Модели представления слов
# Обучите модель представления слов (word2vec, GloVe, fastText или любую другую) на материале корпуса HPAC.
# 1. Продемонстрируйте, как работает поиск синонимов, ассоциаций, лишних слов в обученной модели.
# 2. Визуализируйте топ-1000 слов по частоте без учета стоп-слов (п. 1.1) с помощью TSNE или UMAP (https://umap-learn.readthedocs.io).
#
# ## Часть 3. [6.5 баллов] Классификация текстов
# Задача классификации формулируется так: данный фрагмент фанфика описывают какую-то ситуацию, которая предшествует произнесению заклинания. Требуется по тексту предсказать, какое именно заклинание будет произнесено. Таким образом, заклинание - это фактически метка класса. Основная мера качества – macro $F_1$.
# Обучите несколько классификаторов и сравните их между собой. Оцените качество классификаторов на частых и редких классах. Какие классы чаще всего оказываются перепутаны? Связаны ли ошибки со смыслом заклинаний?
#
# Используйте фрагменты из множества train для обучения, из множества dev для отладки, из множества test – для тестирования и получения итоговых результатов.
#
# 1. [1 балл] Используйте fastText в качестве baseline-классификатора.
# 2. [2 балла] Используйте сверточные сети в качестве более продвинутого классификатора. Поэкспериментируйте с количеством и размерностью фильтров, используйте разные размеры окон, попробуйте использовать $k$-max pooling.
# 3. [2 балла] Используйте рекуррентные сети в качестве альтернативного продвинутого классификатора. Поэкспериментируйте с количеством и размерностью слоев и другими гиперпараметрами.
# 4. [1.5 балла] Попробуйте расширить обучающее множество за счет аугментации данных. Если вам понадобится словарь синонимов, можно использовать WordNet (ниже вы найдете примеры).
#
# [бонус] Используйте результат max pooling'а как эмбеддинг входного текста. Визуализируйте эмбеддинги 500-1000 предложений из обучающего множества и изучите свойства получившегося пространства.
#
# [бонус] Используйте ваш любимый классификатор и любые (честные) способы повышения качества классификации и получите macro $F_1$ больше 0.5.
#
# ## Часть 4. [0.5 балла] Итоги
# Напишите краткое резюме проделанной работы. Читали ли вы сами Гарри Поттера или фанфики о нем и помогло ли вам знание предметной области в выполнении домашнего задания?
#
# ## Бонусная часть. [2 балла] Skip-Gram Negative Sampling
# Самостоятельно реализовать и обучить модель Skip-Gram Negative Sampling. Продемонстрировать качество полученных представлений на конкретный примерах.

# %% [markdown]
# #Загрузка данных и импорты

# %%
import os
import string
import numpy as np
import torch
import matplotlib.pyplot as plt
import re
import logging
import nltk.data
import pandas as pd
import urllib.request

from matplotlib.pyplot import figure
from tqdm import tqdm
from gensim.utils import any2unicode
from torch.utils.data import DataLoader, Dataset
from gensim.models.fasttext import FastText
from torch import nn, relu, optim
from torch.nn import Conv1d, Linear
from sklearn.metrics import f1_score
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
from gensim.parsing.preprocessing import remove_stopwords, strip_punctuation, strip_short
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from gensim.models import word2vec
from nltk.tokenize import sent_tokenize, RegexpTokenizer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from string import punctuation

# %%
# !wget https://www.dropbox.com/s/u0l2fkkmtmjumbx/hpac_lower_tokenized.zip #загружаем необходимые данные
# Out:
# --2023-10-08 08:50:00--  https://www.dropbox.com/s/u0l2fkkmtmjumbx/hpac_lower_tokenized.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/u0l2fkkmtmjumbx/hpac_lower_tokenized.zip [following]
# --2023-10-08 08:50:01--  https://www.dropbox.com/s/raw/u0l2fkkmtmjumbx/hpac_lower_tokenized.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc233bd57dfa9f530e642f2ca697.dl.dropboxusercontent.com/cd/0/inline/CFPtrnvgR2BDIx2RHJWjL4hDj2Ks6H6j-DlyqYF7R1SPWPhg0v6Ix_xMVR71UMGKB0iHuvqhRvyCs6a4ND2OcFbUGHevhS4jvQpTUcwE8V8CvQSX9nSvN3aGhDZ5o8ACE2alkYm2yxn5H5j9NrZ7g8lW/file# [following]
# ...

# %%
# !unzip /content/hpac_lower_tokenized.zip #распаковка
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: hpac_source/4615642
#   inflating: hpac_source/7028138
#   inflating: hpac_source/7525139
#   inflating: hpac_source/5172600
#   inflating: hpac_source/3857376
#   inflating: hpac_source/5349382
#   inflating: hpac_source/4716141
#   inflating: hpac_source/2527816
#   inflating: hpac_source/9002674
#   inflating: hpac_source/12377877
#   inflating: hpac_source/4482433
#   inflating: hpac_source/12561875
#   inflating: hpac_source/3958842
#   inflating: hpac_source/2744273
#   inflating: hpac_source/7534883
#   inflating: hpac_source/9342729
#   inflating: hpac_source/9827191
#   inflating: hpac_source/4085248
#   inflating: hpac_source/2801654
#   inflating: hpac_source/6761621
#   inflating: hpac_source/9744246
#   inflating: hpac_source/2422618
#   inflating: hpac_source/11162505
#   inflating: hpac_source/10956839
#   inflating: hpac_source/3739578
#   inflating: hpac_source/11479461
# ...

# %%
class IterLoading: #класс для итеративной подгрузки данных, чтобы ОЗУ не переполнялось
    def __init__(self, dir):
        self.dir = dir
        self.filenames = [filename for filename in os.listdir(dir)]
        self.index = -1
        self.size = len(self.filenames)

    def __iter__(self):
        return self

    def __next__(self):
        self.index += 1
        if self.index % 3000 == 0:
          print(f"{(self.index/self.size) * 100}%")
        if self.index < self.size:
            with open(self.dir + self.filenames[self.index], 'r') as f:
              tokenized_text = strip_short(strip_punctuation(remove_stopwords(f.read()))).split() #обработка пунктуации, стоп-слов и токенизация
            return tokenized_text
        self.index = -1
        raise StopIteration

# %% [markdown]
# # Часть 1. [1 балл] Эксплоративный анализ

# %%
iters = IterLoading("/content/hpac_source/")

# %%
with open("/content/Harry Potter names", "r") as f:
  hpnames = f.read().split('\n')

# %%
clean_corpus = {}

names = {}
profnames = {}


for tokens in iters: #очистка текстов со счетчиком уникальных слов
  for i in range(len(tokens)):
    if tokens[i] not in clean_corpus.keys():
      clean_corpus[tokens[i]] = 0
    clean_corpus[tokens[i]] += 1

    for name in hpnames: #поиск имен из предварительно загруженного файла и счетчик
      if tokens[i] in name:
        if name not in names.keys():
          names[name] = 0
        names[name] += 1

    if tokens[i-1] == 'professor': #поиск сочетаний со словом профессор и счетчик
      token = tokens[i-1] + ' ' + tokens[i]
      if token not in profnames.keys():
        profnames[token] = 0
      profnames[token] += 1
# Out:
# 0.0%
# 8.281573498964804%
# 16.563146997929607%
# 24.84472049689441%
# 33.126293995859214%
# 41.40786749482402%
# 49.68944099378882%
# 57.971014492753625%
# 66.25258799171843%
# 74.53416149068323%
# 82.81573498964804%
# 91.09730848861284%
# 99.37888198757764%

# %% [markdown]
# 1) Найдите топ-1000 слов по частоте без учета стоп-слов.

# %%
top_1000_words = sorted(clean_corpus.items(), key= lambda x: x[1], reverse=True)[:1000]
top_1000_words
# Out:
# [('harry', 4000516),
#  ('said', 2262365),
#  ('hermione', 1831475),
#  ('draco', 1389987),
#  ('like', 1275302),
#  ('know', 1203944),
#  ('eyes', 1033470),
#  ('time', 1016960),
#  ('ron', 906202),
#  ('looked', 893446),
#  ('asked', 826495),
#  ('head', 737083),
#  ('going', 718864),
#  ('think', 716081),
#  ('face', 657548),
#  ('way', 656364),
#  ('severus', 655654),
#  ('room', 648484),
#  ('hand', 639613),
#  ('ginny', 639548),
#  ('sirius', 630219),
#  ('want', 613217),
#  ('potter', 608426),
#  ('thought', 608150),
#  ('right', 603542),
#  ('snape', 600492),
#  ('away', 580725),
#  ('look', 566544),
#  ('knew', 524841),
#  ('let', 513133),
#  ('good', 510094),
#  ('malfoy', 486352),
#  ('wand', 482520),
#  ('little', 481406),
#  ('felt', 476097),
#  ('dumbledore', 472845),
#  ('turned', 472763),
#  ('james', 468948),
#  ('come', 461133),
#  ('got', 451904),
#  ('took', 436164),
#  ('remus', 433776),
#  ('lily', 423907),
#  ('sure', 414026),
#  ('looking', 412943),
# ...

# %% [markdown]
# 2) Найдите топ-10 по частоте: имен, пар имя + фамилия, пар вида ''профессор'' + имя / фамилия.

# %%
top_10 = sorted(names.items(), key= lambda x: x[1], reverse=True)[:10]
top_10
# Out:
# [('harry potter', 4629024),
#  ('hermione granger', 2295874),
#  ('draco malfoy', 1879576),
#  ('severus snape', 1317845),
#  ('bloody baron', 1210250),
#  ('ronald weasley', 1190823),
#  ('james potter i', 1095258),
#  ('luna lovegood', 1059119),
#  ('lily j. potter', 1050145),
#  ('sirius black', 1018610)]

# %%
top_10_profs = sorted(profnames.items(), key= lambda x: x[1], reverse=True)[:10]
top_10_profs
# Out:
# [('professor snape', 46387),
#  ('professor mcgonagall', 43248),
#  ('professor dumbledore', 24576),
#  ('professor lupin', 10338),
#  ('professor flitwick', 9600),
#  ('professor slughorn', 5941),
#  ('professor sprout', 5807),
#  ('professor harry', 5031),
#  ('professor said', 4614),
#  ('professor trelawney', 3203)]

# %% [markdown]
# # Часть 2. [2 балла] Модели представления слов
#
# Обучите модель представления слов (word2vec, GloVe, fastText или любую другую) на материале корпуса HPAC.

# %%
w2v = Word2Vec(iters) #итеративно обучаем word2vec
# Out:
# 8.281573498964804%
# 16.563146997929607%
# 24.84472049689441%
# 33.126293995859214%
# 41.40786749482402%
# 49.68944099378882%
# 57.971014492753625%
# 66.25258799171843%
# 74.53416149068323%
# 82.81573498964804%
# 91.09730848861284%
# 99.37888198757764%
# 0.0%
# 8.281573498964804%
# 16.563146997929607%
# 24.84472049689441%
# 33.126293995859214%
# 41.40786749482402%
# 49.68944099378882%
# 57.971014492753625%
# 66.25258799171843%
# 74.53416149068323%
# 82.81573498964804%
# 91.09730848861284%
# 99.37888198757764%
# WARNING:gensim.models.word2vec:EPOCH 0: supplied example count (36225) did not equal expected count (35301)
# WARNING:gensim.models.word2vec:EPOCH 0: supplied raw word count (205994146) did not equal expected count (200478874)
# 0.0%
# 8.281573498964804%
# 16.563146997929607%
# 24.84472049689441%
# 33.126293995859214%
# 41.40786749482402%
# 49.68944099378882%
# 57.971014492753625%
# 66.25258799171843%
# 74.53416149068323%
# 82.81573498964804%
# 91.09730848861284%
# ...

# %% [markdown]
# Продемонстрируйте, как работает поиск синонимов, ассоциаций, лишних слов в обученной модели.

# %%
w2v.wv.most_similar(positive=["gryffindor"])
# Out:
# [('griffindor', 0.903619647026062),
#  ('gryfindor', 0.8551317453384399),
#  ('slytherin', 0.8138002753257751),
#  ('ravenclaw', 0.7939249873161316),
#  ('gryffendor', 0.7864972949028015),
#  ('griffyndor', 0.771392822265625),
#  ('hufflepuff', 0.7570362687110901),
#  ('huffelpuff', 0.7512598633766174),
#  ('gryff', 0.7509520053863525),
#  ('gryfinndor', 0.7297720909118652)]

# %% [markdown]
# Ближе всего к слову Гриффиндор (факультет) оказались, ожидаемо, другие написания этого слова, а также названия других факультетов Хогвартса.

# %%
w2v.wv.most_similar(positive=['gryffindor', 'snake'], negative=['lion'])
# Out:
# [('slytherin', 0.6663486361503601),
#  ('gryfindor', 0.5364652276039124),
#  ('griffyndor', 0.5341384410858154),
#  ('slyterin', 0.5266571640968323),
#  ('slytherins', 0.525292158126831),
#  ('griffindor', 0.5234164595603943),
#  ('tacitus', 0.508405327796936),
#  ('ravenclaw', 0.5038302540779114),
#  ('gryffindore', 0.5011152625083923),
#  ('gryffendor', 0.49451151490211487)]

# %% [markdown]
# При сложении векторов Гриффиндор и змея (символ Слизерина) и вычитании слова лев (символ Гриффиндора) получаем первым словом факультет с символом змеи, то есть Слизерин.

# %%
w2v.wv.doesnt_match(['owl', 'wand', 'hat' , 'muggle'])
# Out:
# 'muggle'

# %% [markdown]
# Поиск лишнего слова также срабатывает. Лишним оказывается человек, не владеющий магией (маггл), который явно отличается от предметов, связанных с магией.

# %% [markdown]
# Визуализируйте топ-1000 слов по частоте без учета стоп-слов (п. 1.1) с помощью TSNE или UMAP (https://umap-learn.readthedocs.io).

# %%
vectors = [w2v.wv[item[0]] for item in top_1000_words]
words = [item[0] for item in top_1000_words]

# %%
import umap

# %%
umap_model = umap.UMAP(n_components=2, random_state=42)

# %% [markdown]
# С помощью UMAP визуализируем треть слов, чтобы можно было проанализировать полученные результаты.

# %%
Y = umap_model.fit_transform(vectors[:300]).T
figure(figsize=(15, 15))
plt.scatter(Y[0], Y[1])
for i in range(len(Y[0])):
    plt.annotate(words[i], (Y[0][i], Y[1][i]))
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# Близкие по смыслу слова объединяются в кластеры: имена профессоры, учеников, эмоции, части тела и т.д.

# %%
Y = umap_model.fit_transform(vectors).T
figure(figsize=(10, 10))
plt.scatter(Y[0], Y[1])
for i in range(len(Y[0])):
    plt.annotate(words[i], (Y[0][i], Y[1][i]))
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# На полной картинке мы видим, что слова образуют более плотные кластеры. Но различить отдельные слова уже практически нереально.

# %% [markdown]
# # Часть 3. [6.5 баллов] Классификация текстов
# Задача классификации формулируется так: данный фрагмент фанфика описывают какую-то ситуацию, которая предшествует произнесению заклинания. Требуется по тексту предсказать, какое именно заклинание будет произнесено. Таким образом, заклинание - это фактически метка класса. Основная мера качества – macro $F_1$.
# Обучите несколько классификаторов и сравните их между собой. Оцените качество классификаторов на частых и редких классах. Какие классы чаще всего оказываются перепутаны? Связаны ли ошибки со смыслом заклинаний?
#
# Используйте фрагменты из множества train для обучения, из множества dev для отладки, из множества test – для тестирования и получения итоговых результатов.

# %% [markdown]
# ##Загрузка данных

# %%
# !wget https://www.dropbox.com/s/ftinwwjfyydevth/hpac_splits.zip
# Out:
# --2023-10-14 18:05:00--  https://www.dropbox.com/s/ftinwwjfyydevth/hpac_splits.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/ftinwwjfyydevth/hpac_splits.zip [following]
# --2023-10-14 18:05:01--  https://www.dropbox.com/s/raw/ftinwwjfyydevth/hpac_splits.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf38d8aaeec1ea4b2ec939b0c0a.dl.dropboxusercontent.com/cd/0/inline/CFm-1mMXfqNzoOTBSybkB_iyfePq_eVIcgYYXijqtXHl41M8-VGzFEtGvwXr9SBu_OQsLv5H_OAHKIAPdfl08p7cNMeye6uFoGTOLHi3ZjoKjjzcY799dVHwsjfsDHkyhuD0CPNuIC5H6QnCFOG2VQbN/file# [following]
# ...

# %%
# !unzip hpac_splits
# Out:
# Archive:  hpac_splits.zip
#    creating: hpac_corpus/
#   inflating: hpac_corpus/hpac_training_128.tsv
#    creating: __MACOSX/
#    creating: __MACOSX/hpac_corpus/
#   inflating: __MACOSX/hpac_corpus/._hpac_training_128.tsv
#   inflating: hpac_corpus/hpac_dev_128.tsv
#   inflating: __MACOSX/hpac_corpus/._hpac_dev_128.tsv
#   inflating: hpac_corpus/hpac_test_128.tsv
#   inflating: __MACOSX/hpac_corpus/._hpac_test_128.tsv
#   inflating: __MACOSX/._hpac_corpus

# %%
import pandas as pd
df_train = pd.read_csv('/content/hpac_corpus/hpac_training_128.tsv', sep = '\t', header = None)
df_test = pd.read_csv('/content/hpac_corpus/hpac_test_128.tsv', sep = '\t', header = None)
df_dev = pd.read_csv('/content/hpac_corpus/hpac_dev_128.tsv', sep = '\t', header = None)
df_train.head(5)
# Out:
#                  0             1  \
# 0    7642954.0.676    RIDDIKULUS
# 1  10443333.0.5753    RIDDIKULUS
# 2   4703706.0.8690       STUPEFY
# 3   4593427.0.1815         ACCIO
# 4   4278446.0.2692  EXPELLIARMUS
#
#                                                    2
# 0  were staring at her . she was up next to face ...
# 1  that whole time . her first reaction , for whi...
# 2  we watched his inglorious withdrawal together ...
# 3  my wand , `` incendio . '' this wretched chill...
# 4  already compared ours , they 're the same ever...

# %% [markdown]
# ## FastText base classificator
# [1 балл] Используйте fastText в качестве baseline-классификатора.

# %%
pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199770 sha256=7ef8f919fcab9b82b19d6013d2696903958c87414aa68d55db499a33c2ef1449
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# ...

# %%
import fasttext

# %%
X_train = [example for example in df_train[2]]
y_train = [example for example in df_train[1]]

X_test = [example for example in df_test[2]]
y_test = [example for example in df_test[1]]

# %%
train_file = "train.txt"
test_file = "test.txt"

with open('train.txt', 'w+') as outfile:
    for i in range(len(X_train)):
        outfile.write('__label__' + y_train[i] + ' '+ ' '.join(X_train[i]) + '\n')


with open('test.txt', 'w+') as outfile:
    for i in range(len(X_test)):
        outfile.write('__label__' + y_test[i] + ' ' + ' '.join(X_test[i]) + '\n')

# %%
# Обучим модель fastText
model = fasttext.train_supervised(input='/content/train.txt')

# %%
pred = model.predict([' '.join(x) for x in X_test])[0]
pred = [label[0].split("_")[-1] for label in pred] #получим предсказания

print("F1-measure: {0:6.2f}".format(f1_score(y_test, pred, average='macro')))
# Out:
# F1-measure:   0.01

# %% [markdown]
# ## Нейросетки (предобработка)

# %%
# !pip install torch==2.0.1 torchtext==0.5.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.2
#     Uninstalling torchtext-0.15.2:
#       Successfully uninstalled torchtext-0.15.2
# ...

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
# 2023-10-14 18:06:06.278150: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-14 18:06:08.494569: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-10-14 18:06:10.767257: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
# !pip install torchvision

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
train_clean = df_train.copy()
dev_clean = df_dev.copy()
test_clean = df_test.copy()

# %%
print('Классы: ', train_clean[1].unique())
# Out:
# Классы:  ['RIDDIKULUS' 'STUPEFY' 'ACCIO' 'EXPELLIARMUS' 'PROTEGO' 'LUMOS' 'CRUCIO'
#  'REDUCTO' 'AVADA_KEDAVRA' 'WINGARDIUM_LEVIOSA' 'SCOURGIFY'
#  'PETRIFICUS_TOTALUS' 'INCENDIO' 'DEPRIMO' 'IMPERIO' 'EVANESCO'
#  'ALOHOMORA' 'EXPECTO_PATRONUM' 'REDUCIO' 'OBLIVIATE' 'SONORUS'
#  'SECTUMSEMPRA' 'CONFRINGO' 'LEGILIMENS' 'DIFFINDO' 'TARANTALLEGRA'
#  'OPPUGNO' 'COLLOPORTUS' 'APARECIUM' 'IMPEDIMENTA' 'TERGEO' 'MUFFLIATO'
#  'INCARCEROUS' 'RELASHIO' 'SILENCIO' 'LEVICORPUS' 'LOCOMOTOR' 'AVIS'
#  'MORSMORDRE' 'PROTEGO_TOTALUM' 'REPARO' 'AGUAMENTI' 'EPISKEY' 'NOX'
#  'MOBILICORPUS' 'PORTUS' 'FINITE_INCANTATEM' 'LANGLOCK' 'IMPERVIUS'
#  'ENGORGIO' 'CAVE_INIMICUM' 'SALVIO_HEXIA' 'RENNERVATE' 'POINT_ME'
#  'DENSAUGEO' 'QUIETUS' 'GEMINIO' 'FERULA' 'HOMENUM_REVELIO' 'ORCHIDEOUS'
#  'LOCOMOTOR_MORTIS' 'CONFUNDO' 'DELETRIUS' 'EXPULSO' 'OBSCURO'
#  'PRIOR_INCANTATO' 'RICTUSEMPRA' 'SPECIALIS_REVELIO' 'FLAGRATE'
#  'PIERTOTUM_LOCOMOTOR' 'DEFODIO' 'FURNUNCULUS' 'WADDIWASI'
# ...

# %%
len(train_clean[1].unique())
# Out:
# 85

# %% [markdown]
# Получили 85 разных классов с заклинаниями

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from string import punctuation
punctuation

import re
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import PorterStemmer

porter = PorterStemmer()
token = WordPunctTokenizer()
p = r'@[A-Za-z0-9]+'
stops = set(stopwords.words('english') + list(punctuation))

def text_cleaner(text): # Функция для очистки текстов от знаков пунктуации и приведения к строчным буквам
    clean = re.sub(p, '', text)
    letters = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters.lower()

    words = token.tokenize(lower_case)

    stem_sentence=[]
    for word in words:
        if word not in stops:
          stem_sentence.append(porter.stem(word))
          stem_sentence.append(" ")
    words="".join(stem_sentence).strip()
    return words

# %% [markdown]
# Очистим наши датасеты для обучения, валидации и тестирования.

# %%
for i in range(len(train_clean)):
  train_clean.iloc[i][2] = text_cleaner(train_clean.iloc[i][2])

for i in range(len(test_clean)):
  test_clean.iloc[i][2] = text_cleaner(test_clean.iloc[i][2])

for i in range(len(dev_clean)):
  dev_clean.iloc[i][2] = text_cleaner(dev_clean.iloc[i][2])

train_clean.set_axis([0, 'label', 'text'], axis=1, inplace=True)
test_clean.set_axis([0, 'label', 'text'], axis=1, inplace=True)
dev_clean.set_axis([0, 'label', 'text'], axis=1, inplace=True)
# Out:
# <ipython-input-15-e0acdffeadb3>:10: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   train_clean.set_axis([0, 'label', 'text'], axis=1, inplace=True)
# <ipython-input-15-e0acdffeadb3>:11: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   test_clean.set_axis([0, 'label', 'text'], axis=1, inplace=True)
# <ipython-input-15-e0acdffeadb3>:12: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   dev_clean.set_axis([0, 'label', 'text'], axis=1, inplace=True)

# %%
import torch
from torchtext import data
from torchtext.data import Field, Dataset, Example
import pandas as pd


class DataFrameDataset(Dataset): #класс для использования pandas df в качестве ресурса
    def __init__(self, examples, fields, filter_pred=None):
        self.examples = examples.apply(
            SeriesExample.fromSeries, args=(fields,), axis=1).tolist()
        if filter_pred is not None:
            self.examples = filter(filter_pred, self.examples)
        self.fields = dict(fields)
        # Unpack field tuples
        for n, f in list(self.fields.items()):
            if isinstance(n, tuple):
                self.fields.update(zip(n, f))
                del self.fields[n]

class SeriesExample(data.Example): #класс для преобразования pandas series в тип Example
    def __str__(self):
        return str(self)

    @classmethod
    def fromSeries(cls, data, fields):
        return cls.fromdict(data.to_dict(), fields)

    @classmethod
    def fromdict(cls, data, fields):
        ex = cls()

        for key, field in fields.items():
            if key not in data:
                raise ValueError("Specified key {} was not found in "
                                 "the input data".format(key))
            if field is not None:
                setattr(ex, key, field.preprocess(data[key]))
            else:
                setattr(ex, key, data[key])
        return ex

#ссылка на ресурс: https://github.com/ksopyla/pytorch_neural_networks/blob/master/RNN/dataframe_dataset.py

# %%
import torch
from torchtext import data
from torchtext import datasets
from torchtext.vocab import build_vocab_from_iterator

print(torch.__version__)

SEED = 0
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)


TEXT = data.Field(tokenize = 'spacy', tokenizer_language = 'en_core_web_sm')
LABEL = data.LabelField()
# Out:
# 2.0.1+cu118

# %%
fields = { 'label' : LABEL, 'text' : TEXT }
train_ds = DataFrameDataset(train_clean, fields)
dev_ds = DataFrameDataset(dev_clean, fields)
test_ds = DataFrameDataset(test_clean, fields)

# %%
TEXT.build_vocab(train_ds, max_size=25000)
LABEL.build_vocab(train_ds)

# %%
BATCH_SIZE = 16

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_ds, dev_ds, test_ds),
    batch_size=BATCH_SIZE,
    sort_key=lambda x: len(x.text),
    repeat=False)

# %%
def train_func(model, iterator, optimizer, criterion):
    epoch_loss = 0
    res_preds = 0

    model.train()

    for batch in iterator:
        optimizer.zero_grad()

        predictions = model(batch.text.cuda()).squeeze(1)
        loss = criterion(predictions, batch.label.cuda())
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
    return epoch_loss / len(iterator)

# %%
def evaluate_func(model, iterator, criterion):
    epoch_loss = 0
    res_preds = 0

    model.eval()

    with torch.no_grad():
        for batch in iterator:
            predictions = model(batch.text.cuda()).squeeze(1)

            loss = criterion(predictions, batch.label.cuda())
            epoch_loss += loss
    return epoch_loss / len(iterator)

# %%
TEXT.build_vocab(train_ds, max_size=25000, vectors="glove.6B.100d")
LABEL.build_vocab(train_ds)


BATCH_SIZEBATCH_S  = 16

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_ds, dev_ds, test_ds),
    batch_size=BATCH_SIZE,
    sort_key=lambda x: len(x.text),
    repeat=False)
# Out:
# .vector_cache/glove.6B.zip: 862MB [02:39, 5.41MB/s]
# 100%|█████████▉| 399999/400000 [00:14<00:00, 27979.31it/s]

# %% [markdown]
# ## CNN
# [2 балла] Используйте сверточные сети в качестве более продвинутого классификатора. Поэкспериментируйте с количеством и размерностью фильтров, используйте разные размеры окон, попробуйте использовать  k -max pooling.

# %%
import torch.nn as nn

class CNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.conv_0 = nn.Conv2d(in_channels=1, out_channels=n_filters, kernel_size=(filter_sizes[0], embedding_dim))
        self.conv_1 = nn.Conv2d(in_channels=1, out_channels=n_filters, kernel_size=(filter_sizes[1], embedding_dim))
        self.conv_2 = nn.Conv2d(in_channels=1, out_channels=n_filters, kernel_size=(filter_sizes[2], embedding_dim))
        self.fc = nn.Linear(len(filter_sizes) * n_filters, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        #x = [sent len, batch size]
        x = x.permute(1, 0)

        #x = [batch size, sent len]
        embedded = self.embedding(x)

        #embedded = [batch size, sent len, emb dim]
        embedded = embedded.unsqueeze(1)

        #embedded = [batch size, 1, sent len, emb dim]
        conved_0 = nn.functional.relu(self.conv_0(embedded).squeeze(3))
        conved_1 = nn.functional.relu(self.conv_1(embedded).squeeze(3))
        conved_2 = nn.functional.relu(self.conv_2(embedded).squeeze(3))

        #conv_n = [batch size, n_filters, sent len - filter_sizes[n]]
        pooled_0 = nn.functional.max_pool1d(conved_0, conved_0.shape[2]).squeeze(2)
        pooled_1 = nn.functional.max_pool1d(conved_1, conved_1.shape[2]).squeeze(2)
        pooled_2 = nn.functional.max_pool1d(conved_2, conved_2.shape[2]).squeeze(2)

        #pooled_n = [batch size, n_filters]
        cat = self.dropout(torch.cat((pooled_0, pooled_1, pooled_2), dim=1))

        #cat = [batch size, n_filters * len(filter_sizes)]
        return self.fc(cat)

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
N_FILTERS = 250
FILTER_SIZES = [2,3,4]
OUTPUT_DIM = len(LABEL.vocab)
DROPOUT = 0.5

model = CNN(INPUT_DIM, EMBEDDING_DIM, N_FILTERS, FILTER_SIZES, OUTPUT_DIM, DROPOUT)

# %%
TEXT.build_vocab(train_ds, max_size=25000, vectors="glove.6B.100d")
LABEL.build_vocab(train_ds)

pretrained_embeddings = TEXT.vocab.vectors
model.embedding.weight.data.copy_(pretrained_embeddings)
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-1.0889,  0.1550,  0.3195,  ..., -0.5389, -0.0420, -0.2176],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6714, -0.0377, -0.5189,  ..., -0.3430,  0.1925,  0.3466]])

# %%
BATCH_SIZE  = 64

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_ds, dev_ds, test_ds),
    batch_size=BATCH_SIZE,
    sort_key=lambda x: len(x.text),
    repeat=False)

# %%
# !nvidia-smi
# Out:
# Wed Oct 11 11:05:48 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch.optim as optim

optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

model = model.cuda()

# %%
N_EPOCHS = 15

for epoch in range(N_EPOCHS):
    train_loss = train_func(model, train_iterator, optimizer, criterion)
    valid_loss = evaluate_func(model, valid_iterator, criterion)

    print(f'Epoch: {epoch+1:02}, Train Loss: {train_loss:.3f}, Val. Loss: {valid_loss:.3f}')
# Out:
# Epoch: 01, Train Loss: 3.171, Val. Loss: 2.963
# Epoch: 02, Train Loss: 2.799, Val. Loss: 2.874
# Epoch: 03, Train Loss: 2.595, Val. Loss: 2.844
# Epoch: 04, Train Loss: 2.408, Val. Loss: 2.835
# Epoch: 05, Train Loss: 2.220, Val. Loss: 2.875
# Epoch: 06, Train Loss: 2.031, Val. Loss: 2.937
# Epoch: 07, Train Loss: 1.849, Val. Loss: 3.005
# Epoch: 08, Train Loss: 1.669, Val. Loss: 3.119
# Epoch: 09, Train Loss: 1.512, Val. Loss: 3.238
# Epoch: 10, Train Loss: 1.371, Val. Loss: 3.351
# Epoch: 11, Train Loss: 1.253, Val. Loss: 3.513
# Epoch: 12, Train Loss: 1.143, Val. Loss: 3.628
# Epoch: 13, Train Loss: 1.050, Val. Loss: 3.768
# Epoch: 14, Train Loss: 0.966, Val. Loss: 3.910
# Epoch: 15, Train Loss: 0.901, Val. Loss: 4.072

# %%
preds = []
y_true = []
for batch in test_iterator:
        predictions = model(batch.text.cuda()).squeeze(1)
        _, predicted = torch.max(predictions, 1)
        preds.extend(predicted)
        y_true.extend(batch.label.cuda())

# %%
preds_list = [preds[i].item() for i in range(len(preds))]
y_true_list =  [y_true[i].item() for i in range(len(y_true))]

# %%
f1_score(y_true_list, preds_list, average='macro')
# Out:
# 0.13896421366697928

# %% [markdown]
# ## RNN
# [2 балла] Используйте рекуррентные сети в качестве альтернативного продвинутого классификатора. Поэкспериментируйте с количеством и размерностью слоев и другими гиперпараметрами.

# %%
import torch
from torchtext import data
from torchtext import datasets
from torchtext.vocab import build_vocab_from_iterator

print(torch.__version__)

SEED = 0
torch.manual_seed(SEED)


TEXT = data.Field(tokenize = 'spacy', tokenizer_language = 'en_core_web_sm', include_lengths=True)
LABEL = data.LabelField()
# Out:
# 2.0.1+cu118

# %%
fields = { 'label' : LABEL, 'text' : TEXT }
train_ds = DataFrameDataset(train_clean[train_clean['text'].str.len() != 0], fields)
dev_ds = DataFrameDataset(dev_clean[dev_clean['text'].str.len() != 0], fields)
test_ds = DataFrameDataset(test_clean[test_clean['text'].str.len() != 0], fields)

# %%
TEXT.build_vocab(train_ds, max_size=25000, vectors = "glove.6B.100d", unk_init = torch.Tensor.normal_)
LABEL.build_vocab(train_ds)

# %%
BATCH_SIZE = 64

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_ds, dev_ds, test_ds),
    batch_size = BATCH_SIZE,
    sort_key=lambda x: len(x.text),
    repeat=False,
    device = device)

# %%
class RNN(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout, pad_idx):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, emb_dim, padding_idx=pad_idx)
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim
        self.rnn = nn.LSTM(
                        emb_dim,
                        hidden_dim,
                        num_layers=n_layers,
                        bidirectional=bidirectional,
                        dropout=dropout)
        self.fc = nn.Linear(hidden_dim * 2, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, input, input_lengths):
        batch_size = input.shape[1]
        embedded = self.embedding(input)
        embedded = self.dropout(embedded)

        # packing the sequence
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths.to('cpu'), enforce_sorted=False)

        packed_output, (hidden, cell) = self.rnn(packed_embedded)

        # unpacking the sequence
        output, output_lengths = nn.utils.rnn.pad_packed_sequence(packed_output)

        hidden = hidden.view(self.n_layers, -1 , batch_size, self.hidden_dim)

        # concatinating final forward and final backward hidden states
        hidden = torch.cat((hidden[-1][0][:], hidden[-1][1][:]), dim=1)

        hidden = self.dropout(hidden)

        return self.fc(hidden)

# %%
# Инициализация параметров модели и данных

INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIM = 250
OUTPUT_DIM = len(LABEL.vocab)
NUM_LAYERS = 2
#BIDIRECTIONAL = True
DROPOUT = 0.5
PAD_IDX = TEXT.vocab.stoi[TEXT.pad_token]

model = RNN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, NUM_LAYERS, True, DROPOUT, PAD_IDX)

# %%
pretrained_embeddings = TEXT.vocab.vectors
model.embedding.weight.data.copy_(pretrained_embeddings)
# Out:
# tensor([[-1.1258, -1.1524, -0.2506,  ..., -0.3334, -0.4288,  0.2329],
#         [ 0.9625,  0.3492, -0.9215,  ...,  1.4503, -0.0519, -0.6284],
#         [-1.0889,  0.1550,  0.3195,  ..., -0.5389, -0.0420, -0.2176],
#         ...,
#         [ 0.9808,  0.5882,  0.9444,  ..., -0.7513,  0.8135, -2.5529],
#         [ 1.1108, -1.0840,  0.7595,  ...,  0.7560, -0.9742,  1.6510],
#         [ 0.6714, -0.0377, -0.5189,  ..., -0.3430,  0.1925,  0.3466]])

# %%
UNK_IDX = TEXT.vocab.stoi[TEXT.unk_token] # получаем индекс UNK в словаре TEXT.vocab

#инициализации векторов слов UNK и PAD в матрице весов эмбеддингов модели перед обучением
model.embedding.weight.data[UNK_IDX] = torch.zeros(EMBEDDING_DIM)
model.embedding.weight.data[PAD_IDX] = torch.zeros(EMBEDDING_DIM)

# %%
import torch.optim as optim

optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

model = model.to(device)
criterion = criterion.to(device)

# %%
def train(model, iterator, optimizer, criterion):
    epoch_loss = 0
    epoch_acc = 0

    model.train()

    for batch in iterator:
        optimizer.zero_grad()

        input, input_lengths = batch.text

        preds = model(input.cuda(), input_lengths.cuda()).squeeze(1)

        loss = criterion(preds, batch.label.cuda())
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    epoch_loss = 0
    epoch_acc = 0

    model.eval()

    for batch in iterator:
        input, input_lengths = batch.text

        preds = model(input.cuda(), input_lengths.cuda()).squeeze(1)

        loss = criterion(preds, batch.label.cuda())

        epoch_loss += loss.item()
    return epoch_loss / len(iterator)

# %%
N_EPOCHS = 15

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    train_loss = train(model, train_iterator, optimizer, criterion)
    valid_loss = evaluate(model, valid_iterator, criterion)

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'best_model.pt')

    print(f'Epoch: {epoch+1:02}, Train Loss: {train_loss:.3f}, Val. Loss: {valid_loss:.3f}')

model.load_state_dict(torch.load('best_model.pt'))
# Out:
# Epoch: 01, Train Loss: 2.506, Val. Loss: 2.639
# Epoch: 02, Train Loss: 2.456, Val. Loss: 2.646
# Epoch: 03, Train Loss: 2.405, Val. Loss: 2.629
# Epoch: 04, Train Loss: 2.361, Val. Loss: 2.627
# Epoch: 05, Train Loss: 2.319, Val. Loss: 2.634
# Epoch: 06, Train Loss: 2.280, Val. Loss: 2.616
# Epoch: 07, Train Loss: 2.238, Val. Loss: 2.630
# Epoch: 08, Train Loss: 2.201, Val. Loss: 2.649
# Epoch: 09, Train Loss: 2.171, Val. Loss: 2.664
# Epoch: 10, Train Loss: 2.136, Val. Loss: 2.675
# Epoch: 11, Train Loss: 2.102, Val. Loss: 2.665
# Epoch: 12, Train Loss: 2.072, Val. Loss: 2.701
# Epoch: 13, Train Loss: 2.039, Val. Loss: 2.721
# Epoch: 14, Train Loss: 2.016, Val. Loss: 2.744
# Epoch: 15, Train Loss: 1.986, Val. Loss: 2.728
# <All keys matched successfully>

# %%
preds = []
y_true = []
for batch in test_iterator:
        input, input_lengths = batch.text
        predictions = model(input.cuda(), input_lengths.cuda()).squeeze(1)
        _, predicted = torch.max(predictions, 1)
        preds.extend(predicted)
        y_true.extend(batch.label.cuda())

# %%
preds_list = [preds[i].item() for i in range(len(preds))]
y_true_list =  [y_true[i].item() for i in range(len(y_true))]

# %%
f1_score(y_true_list, preds_list, average='macro')
# Out:
# 0.1331588147834092

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_true_list, preds_list, target_names=['RIDDIKULUS', 'STUPEFY', 'ACCIO', 'EXPELLIARMUS', 'PROTEGO',
       'LUMOS', 'CRUCIO', 'REDUCTO', 'AVADA_KEDAVRA',
       'WINGARDIUM_LEVIOSA', 'SCOURGIFY', 'PETRIFICUS_TOTALUS',
       'INCENDIO', 'DEPRIMO', 'IMPERIO', 'EVANESCO', 'ALOHOMORA',
       'EXPECTO_PATRONUM', 'REDUCIO', 'OBLIVIATE', 'SONORUS',
       'SECTUMSEMPRA', 'CONFRINGO', 'LEGILIMENS', 'DIFFINDO',
       'TARANTALLEGRA', 'OPPUGNO', 'COLLOPORTUS', 'APARECIUM',
       'IMPEDIMENTA', 'TERGEO', 'MUFFLIATO', 'INCARCEROUS', 'RELASHIO',
       'SILENCIO', 'LEVICORPUS', 'LOCOMOTOR', 'AVIS', 'MORSMORDRE',
       'PROTEGO_TOTALUM', 'REPARO', 'AGUAMENTI', 'EPISKEY', 'NOX',
       'MOBILICORPUS', 'PORTUS', 'FINITE_INCANTATEM', 'LANGLOCK',
       'IMPERVIUS', 'ENGORGIO', 'CAVE_INIMICUM', 'SALVIO_HEXIA',
       'RENNERVATE', 'POINT_ME', 'DENSAUGEO', 'QUIETUS', 'GEMINIO',
       'FERULA', 'HOMENUM_REVELIO', 'ORCHIDEOUS', 'LOCOMOTOR_MORTIS',
       'CONFUNDO', 'DELETRIUS', 'EXPULSO', 'OBSCURO', 'PRIOR_INCANTATO',
       'RICTUSEMPRA', 'SPECIALIS_REVELIO', 'FLAGRATE',
       'PIERTOTUM_LOCOMOTOR', 'DEFODIO', 'FURNUNCULUS', 'WADDIWASI',
       'METEOLOJINX_RECANTO', 'PROTEGO_HORRIBILIS', 'LIBERACORPUS',
       'SERPENSORTIA', 'REPELLO_MUGGLETUM', 'ANAPNEO', 'DURO',
       'MOBILIARBUS', 'GLISSEO', 'DESCENDO', 'ERECTO']))
# Out:
#                      precision    recall  f1-score   support
#
#          RIDDIKULUS       0.41      0.64      0.50       914
#             STUPEFY       0.43      0.56      0.49       906
#               ACCIO       0.29      0.51      0.37       516
#        EXPELLIARMUS       0.47      0.60      0.53       501
#             PROTEGO       0.20      0.35      0.26       423
#               LUMOS       0.41      0.37      0.39       370
#              CRUCIO       0.25      0.21      0.22       335
#             REDUCTO       0.60      0.44      0.51       225
#       AVADA_KEDAVRA       0.66      0.59      0.62       221
#  WINGARDIUM_LEVIOSA       0.28      0.14      0.19       175
#           SCOURGIFY       0.13      0.06      0.08       205
#  PETRIFICUS_TOTALUS       0.47      0.49      0.48       164
#            INCENDIO       0.45      0.45      0.45       157
#             DEPRIMO       0.27      0.13      0.18       164
# ...

# %% [markdown]
# Качество классификации напрямую зависит от частоты встречаемости класса, мы видим это в отчете о классификации.

# %%
from sklearn.metrics import confusion_matrix

# Построение матрицы путаницы
conf_matrix = confusion_matrix(y_true_list, preds_list)

# Визуализация матрицы путаницы
plt.figure(figsize =(16, 16))
plt.imshow(conf_matrix, cmap='Blues')
plt.colorbar()
plt.xticks(np.arange(84), ['RIDDIKULUS', 'STUPEFY', 'ACCIO', 'EXPELLIARMUS', 'PROTEGO',
       'LUMOS', 'CRUCIO', 'REDUCTO', 'AVADA_KEDAVRA',
       'WINGARDIUM_LEVIOSA', 'SCOURGIFY', 'PETRIFICUS_TOTALUS',
       'INCENDIO', 'DEPRIMO', 'IMPERIO', 'EVANESCO', 'ALOHOMORA',
       'EXPECTO_PATRONUM', 'REDUCIO', 'OBLIVIATE', 'SONORUS',
       'SECTUMSEMPRA', 'CONFRINGO', 'LEGILIMENS', 'DIFFINDO',
       'TARANTALLEGRA', 'OPPUGNO', 'COLLOPORTUS', 'APARECIUM',
       'IMPEDIMENTA', 'TERGEO', 'MUFFLIATO', 'INCARCEROUS', 'RELASHIO',
       'SILENCIO', 'LEVICORPUS', 'LOCOMOTOR', 'AVIS', 'MORSMORDRE',
       'PROTEGO_TOTALUM', 'REPARO', 'AGUAMENTI', 'EPISKEY', 'NOX',
       'MOBILICORPUS', 'PORTUS', 'FINITE_INCANTATEM', 'LANGLOCK',
       'IMPERVIUS', 'ENGORGIO', 'CAVE_INIMICUM', 'SALVIO_HEXIA',
       'RENNERVATE', 'POINT_ME', 'DENSAUGEO', 'QUIETUS', 'GEMINIO',
       'FERULA', 'HOMENUM_REVELIO', 'ORCHIDEOUS', 'LOCOMOTOR_MORTIS',
       'CONFUNDO', 'DELETRIUS', 'EXPULSO', 'OBSCURO', 'PRIOR_INCANTATO',
       'RICTUSEMPRA', 'SPECIALIS_REVELIO', 'FLAGRATE',
       'PIERTOTUM_LOCOMOTOR', 'DEFODIO', 'FURNUNCULUS', 'WADDIWASI',
       'METEOLOJINX_RECANTO', 'PROTEGO_HORRIBILIS', 'LIBERACORPUS',
       'SERPENSORTIA', 'REPELLO_MUGGLETUM', 'ANAPNEO', 'DURO',
       'MOBILIARBUS', 'GLISSEO', 'DESCENDO', 'ERECTO'], rotation='vertical')
plt.yticks(np.arange(84), ['RIDDIKULUS', 'STUPEFY', 'ACCIO', 'EXPELLIARMUS', 'PROTEGO',
       'LUMOS', 'CRUCIO', 'REDUCTO', 'AVADA_KEDAVRA',
       'WINGARDIUM_LEVIOSA', 'SCOURGIFY', 'PETRIFICUS_TOTALUS',
       'INCENDIO', 'DEPRIMO', 'IMPERIO', 'EVANESCO', 'ALOHOMORA',
       'EXPECTO_PATRONUM', 'REDUCIO', 'OBLIVIATE', 'SONORUS',
       'SECTUMSEMPRA', 'CONFRINGO', 'LEGILIMENS', 'DIFFINDO',
       'TARANTALLEGRA', 'OPPUGNO', 'COLLOPORTUS', 'APARECIUM',
       'IMPEDIMENTA', 'TERGEO', 'MUFFLIATO', 'INCARCEROUS', 'RELASHIO',
       'SILENCIO', 'LEVICORPUS', 'LOCOMOTOR', 'AVIS', 'MORSMORDRE',
       'PROTEGO_TOTALUM', 'REPARO', 'AGUAMENTI', 'EPISKEY', 'NOX',
       'MOBILICORPUS', 'PORTUS', 'FINITE_INCANTATEM', 'LANGLOCK',
       'IMPERVIUS', 'ENGORGIO', 'CAVE_INIMICUM', 'SALVIO_HEXIA',
       'RENNERVATE', 'POINT_ME', 'DENSAUGEO', 'QUIETUS', 'GEMINIO',
       'FERULA', 'HOMENUM_REVELIO', 'ORCHIDEOUS', 'LOCOMOTOR_MORTIS',
       'CONFUNDO', 'DELETRIUS', 'EXPULSO', 'OBSCURO', 'PRIOR_INCANTATO',
       'RICTUSEMPRA', 'SPECIALIS_REVELIO', 'FLAGRATE',
       'PIERTOTUM_LOCOMOTOR', 'DEFODIO', 'FURNUNCULUS', 'WADDIWASI',
       'METEOLOJINX_RECANTO', 'PROTEGO_HORRIBILIS', 'LIBERACORPUS',
       'SERPENSORTIA', 'REPELLO_MUGGLETUM', 'ANAPNEO', 'DURO',
       'MOBILIARBUS', 'GLISSEO', 'DESCENDO', 'ERECTO'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# По матрице путаницы видно, что чаще всего путаются riddikulus (заклинание для изгнания боггарта) и stupefy (оглушающее заклинание). Скорее всего из-за того, что они похожи на английские ridiculous и stupid, имеющие схожие значения. Однако сами заклинания не имеют ничего общего.
#
# Также с этими двумя заклинаниями иногда путаются protego (защитное заклинание), lumos (световое заклинение) и crucio (заклинание терзания).
# Возможно, потому что все эти 5 заклинаний самые популярные и почти все применяются при борьбе.

# %% [markdown]
# ## Аугментация
# [1.5 балла] Попробуйте расширить обучающее множество за счет аугментации данных. Если вам понадобится словарь синонимов, можно использовать WordNet (ниже вы найдете примеры).

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet

def augment_text_with_synonyms(text):
    augmented_text = []
    words = text.split()
    for word in words:
        synonyms = []
        for syn in wordnet.synsets(word):
            for lemma in syn.lemmas():
                synonyms.append(lemma.name())
        if synonyms:
            word = synonyms[0]  # замена слова на первый найденный синоним
        augmented_text.append(word)
    return ' '.join(augmented_text)

# %%
df_train_aug = []
for i in range(len(train_clean)):
    text = train_clean['text'][i]
    augmented_text = augment_text_with_synonyms(text)
    df_train_aug.append({'text': augmented_text, 'label': train_clean['label'][i]})

df_train_aug = pd.DataFrame(df_train_aug)
df_train_aug = pd.concat([train_clean, df_train_aug], ignore_index=True) #расширяем датафрейм за счет добавленных синонимов

# %%
fields = { 'label' : LABEL, 'text' : TEXT }
train_ds_aug = DataFrameDataset(df_train_aug, fields)
dev_ds = DataFrameDataset(dev_clean, fields)
test_ds = DataFrameDataset(test_clean, fields)

# %%
TEXT.build_vocab(train_ds_aug, max_size=40000)
LABEL.build_vocab(train_ds_aug)

# %%
BATCH_SIZE = 16

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_ds_aug, dev_ds, test_ds),
    batch_size=BATCH_SIZE,
    sort_key=lambda x: len(x.text),
    repeat=False)

# %%
TEXT.build_vocab(train_ds_aug, max_size=40000, vectors="glove.6B.100d")
LABEL.build_vocab(train_ds_aug)


BATCH_SIZEBATCH_S  = 16

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_ds_aug, dev_ds, test_ds),
    batch_size=BATCH_SIZE,
    sort_key=lambda x: len(x.text),
    repeat=False)

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
N_FILTERS = 250
FILTER_SIZES = [2,3,4]
OUTPUT_DIM = len(LABEL.vocab)
DROPOUT = 0.5

model = CNN(INPUT_DIM, EMBEDDING_DIM, N_FILTERS, FILTER_SIZES, OUTPUT_DIM, DROPOUT)

# %%
TEXT.build_vocab(train_ds_aug, max_size=40000, vectors="glove.6B.100d")
LABEL.build_vocab(train_ds_aug)

pretrained_embeddings = TEXT.vocab.vectors
model.embedding.weight.data.copy_(pretrained_embeddings)
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.5621, -0.7073,  0.4285,  ...,  0.1691, -0.5292, -0.2885],
#         ...,
#         [ 0.2860,  0.1473,  0.1693,  ..., -1.7042,  0.0681,  0.5318],
#         [ 0.1371,  0.1606, -0.4980,  ..., -0.5031,  0.2237,  0.3773],
#         [-0.0098,  0.3586, -0.4449,  ...,  0.7588,  0.0910,  0.1430]])

# %%
BATCH_SIZE  = 64

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_ds_aug, dev_ds, test_ds),
    batch_size=BATCH_SIZE,
    sort_key=lambda x: len(x.text),
    repeat=False)

# %%
import torch.optim as optim

optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

model = model.cuda()

# %%
N_EPOCHS = 15

for epoch in range(N_EPOCHS):
    train_loss = train_func(model, train_iterator, optimizer, criterion)
    valid_loss = evaluate_func(model, valid_iterator, criterion)

    print(f'Epoch: {epoch+1:02}, Train Loss: {train_loss:.3f}, Val. Loss: {valid_loss:.3f}')
# Out:
# Epoch: 01, Train Loss: 3.011, Val. Loss: 2.897
# Epoch: 02, Train Loss: 2.574, Val. Loss: 2.843
# Epoch: 03, Train Loss: 2.255, Val. Loss: 2.925
# Epoch: 04, Train Loss: 1.926, Val. Loss: 3.087
# Epoch: 05, Train Loss: 1.627, Val. Loss: 3.290
# Epoch: 06, Train Loss: 1.373, Val. Loss: 3.573
# Epoch: 07, Train Loss: 1.171, Val. Loss: 3.894
# Epoch: 08, Train Loss: 1.010, Val. Loss: 4.192
# Epoch: 09, Train Loss: 0.889, Val. Loss: 4.511
# Epoch: 10, Train Loss: 0.789, Val. Loss: 4.851
# Epoch: 11, Train Loss: 0.709, Val. Loss: 5.165
# Epoch: 12, Train Loss: 0.646, Val. Loss: 5.470
# Epoch: 13, Train Loss: 0.588, Val. Loss: 5.830
# Epoch: 14, Train Loss: 0.548, Val. Loss: 6.087
# Epoch: 15, Train Loss: 0.512, Val. Loss: 6.379

# %%
preds = []
y_true = []
for batch in test_iterator:
        predictions = model(batch.text.cuda()).squeeze(1)
        _, predicted = torch.max(predictions, 1)
        preds.extend(predicted)
        y_true.extend(batch.label.cuda())

# %%
preds_list = [preds[i].item() for i in range(len(preds))]
y_true_list =  [y_true[i].item() for i in range(len(y_true))]

# %%
f1_score(y_true_list, preds_list, average='macro')
# Out:
# 0.1277851188106595

# %% [markdown]
# После добавления синонимов macro f1 даже уменьшился на 1%, но в целом, учитывая неустойчивость результатов, можно сказать, что добавление синонимов ощутимо не повлияло на качество классификации.

# %% [markdown]
# # Часть 4. [0.5 балла] Итоги

# %% [markdown]
# Напишите краткое резюме проделанной работы. Читали ли вы сами Гарри Поттера или фанфики о нем и помогло ли вам знание предметной области в выполнении домашнего задания?

# %% [markdown]
# В ходе работы был выполнен экспоративный анализ текстов, включающий в себя анализ частоты употребления слов и словосочетаний.
#
# Выполнена предобработка текстов для обеспечения качественного результата после подачи в модель (очистка от знаков пунктуации и стоп-слов). Обучена модель представления слов Word2Vec и выполнена визуализация семантического пространства с помощью метода UMAP. (UMAP — это алгоритм снижения размерности и мощный инструмент анализа данных. Он похож на PCA (Principal Component Analysis) в смысле скорости и напоминает t-SNE в смысле уменьшения размерности, сохраняя как можно больше информации набора данных.)
#
# Обучено 3 текстовых классификатора:
#
#
# *   Базовый классификатор FastText (f1 macro: 0.01)
# *   CNN классификатор (f1 macro: ~0.13)
# *   RNN классификатор (f1 macro: ~0.13)
#
# Также для CNN классификатора было выполнено расширение обучающего множества за счет аугментации данных, что не дало существенного изменения целевой метрики (f1 macro: ~0.12).

# %% [markdown]
# Знание предметной области немного помогло в выполнении домашнего задания разве что с точки зрения заинтересованности :)
#
# Но то, что многие вещи для работы с синонимами/антонимами и матрицей путаницы не пришлось гуглить, несомненно, радует.
